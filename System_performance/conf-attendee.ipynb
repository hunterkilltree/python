# %%
from random import randint
import simpy

TALKS_PER_PERSON = 3
TALK_LENGTH = 30
BREAK_LENGTH = 15

def attendee(env, name, knowledge = 0, hunger = 0):
    while True:
        # visit talks
        for i in range(TALKS_PER_PERSON):
            knowledge += randint( 0, 3 )/(1 + hunger)
            hunger += randint( 1, 4 )

            yield env.timeout( TALK_LENGTH )

        print( 'Attendee %s finished talks with knowledge %.2f and hunger %.2f' % (name, knowledge, hunger))

        # go buffet
        food = randint( 3, 12 )
        hunger -= min( food, hunger )

        yield env.timeout( BREAK_LENGTH )

        print( 'Attendee %s finished eating with hunger %.2f' % (name, hunger))

env = simpy.Environment()
for i in range( 3 ):
    env.process( attendee(env, i ) )
env.run( until = 2200 )
# Out:
# Attendee 0 finished talks with knowledge 2.60 and hunger 11.00
# Attendee 1 finished talks with knowledge 3.83 and hunger 6.00
# Attendee 2 finished talks with knowledge 0.83 and hunger 7.00
# Attendee 0 finished eating with hunger 5.00
# Attendee 1 finished eating with hunger 0.00
# Attendee 2 finished eating with hunger 3.00
# Attendee 0 finished talks with knowledge 3.83 and hunger 13.00
# Attendee 1 finished talks with knowledge 5.67 and hunger 5.00
# Attendee 2 finished talks with knowledge 1.49 and hunger 10.00
# Attendee 0 finished eating with hunger 8.00
# Attendee 1 finished eating with hunger 0.00
# Attendee 2 finished eating with hunger 3.00
# Attendee 0 finished talks with knowledge 4.12 and hunger 13.00
# Attendee 1 finished talks with knowledge 6.81 and hunger 7.00
# Attendee 2 finished talks with knowledge 1.98 and hunger 9.00
# Attendee 0 finished eating with hunger 10.00
# Attendee 1 finished eating with hunger 0.00
# Attendee 2 finished eating with hunger 4.00
# Attendee 0 finished talks with knowledge 4.60 and hunger 18.00
# Attendee 1 finished talks with knowledge 8.18 and hunger 10.00
# Attendee 2 finished talks with knowledge 2.28 and hunger 13.00
# Attendee 0 finished eating with hunger 8.00
# Attendee 1 finished eating with hunger 0.00
# Attendee 2 finished eating with hunger 1.00
# Attendee 0 finished talks with knowledge 4.91 and hunger 16.00
# Attendee 1 finished talks with knowledge 9.93 and hunger 8.00
# Attendee 2 finished talks with knowledge 3.78 and hunger 7.00
# Attendee 0 finished eating with hunger 13.00
# Attendee 1 finished eating with hunger 0.00
# Attendee 2 finished eating with hunger 2.00
# Attendee 0 finished talks with knowledge 5.40 and hunger 19.00
# Attendee 1 finished talks with knowledge 12.08 and hunger 10.00
# Attendee 2 finished talks with knowledge 5.34 and hunger 9.00
# Attendee 0 finished eating with hunger 15.00
# Attendee 1 finished eating with hunger 7.00
# Attendee 2 finished eating with hunger 6.00
# Attendee 0 finished talks with knowledge 5.58 and hunger 21.00
# Attendee 1 finished talks with knowledge 12.62 and hunger 11.00
# Attendee 2 finished talks with knowledge 5.92 and hunger 13.00
# Attendee 0 finished eating with hunger 17.00
# Attendee 1 finished eating with hunger 1.00
# Attendee 2 finished eating with hunger 6.00
# Attendee 0 finished talks with knowledge 5.69 and hunger 21.00
# Attendee 1 finished talks with knowledge 14.55 and hunger 10.00
# Attendee 2 finished talks with knowledge 6.70 and hunger 16.00
# Attendee 0 finished eating with hunger 11.00
# Attendee 1 finished eating with hunger 4.00
# Attendee 2 finished eating with hunger 12.00
# Attendee 0 finished talks with knowledge 5.93 and hunger 18.00
# Attendee 1 finished talks with knowledge 14.98 and hunger 11.00
# Attendee 2 finished talks with knowledge 6.76 and hunger 19.00
# Attendee 0 finished eating with hunger 7.00
# Attendee 1 finished eating with hunger 6.00
# Attendee 2 finished eating with hunger 13.00
# Attendee 0 finished talks with knowledge 6.25 and hunger 14.00
# Attendee 1 finished talks with knowledge 15.42 and hunger 16.00
# Attendee 2 finished talks with knowledge 7.04 and hunger 23.00
# Attendee 0 finished eating with hunger 10.00
# Attendee 1 finished eating with hunger 7.00
# Attendee 2 finished eating with hunger 18.00
# Attendee 0 finished talks with knowledge 6.40 and hunger 19.00
# Attendee 1 finished talks with knowledge 15.62 and hunger 14.00
# Attendee 2 finished talks with knowledge 7.39 and hunger 22.00
# Attendee 0 finished eating with hunger 12.00
# Attendee 1 finished eating with hunger 10.00
# Attendee 2 finished eating with hunger 16.00
# Attendee 0 finished talks with knowledge 6.48 and hunger 23.00
# Attendee 1 finished talks with knowledge 15.69 and hunger 15.00
# Attendee 2 finished talks with knowledge 7.66 and hunger 24.00
# Attendee 0 finished eating with hunger 18.00
# Attendee 1 finished eating with hunger 6.00
# Attendee 2 finished eating with hunger 16.00
# Attendee 0 finished talks with knowledge 6.70 and hunger 25.00
# Attendee 1 finished talks with knowledge 16.47 and hunger 14.00
# Attendee 2 finished talks with knowledge 7.98 and hunger 21.00
# Attendee 0 finished eating with hunger 22.00
# Attendee 1 finished eating with hunger 9.00
# Attendee 2 finished eating with hunger 14.00
# Attendee 0 finished talks with knowledge 6.91 and hunger 26.00
# Attendee 1 finished talks with knowledge 16.90 and hunger 16.00
# Attendee 2 finished talks with knowledge 8.08 and hunger 20.00
# Attendee 0 finished eating with hunger 23.00
# Attendee 1 finished eating with hunger 10.00
# Attendee 2 finished eating with hunger 10.00
# Attendee 0 finished talks with knowledge 6.99 and hunger 32.00
# Attendee 1 finished talks with knowledge 17.33 and hunger 15.00
# Attendee 2 finished talks with knowledge 8.55 and hunger 19.00
# Attendee 0 finished eating with hunger 28.00
# Attendee 1 finished eating with hunger 10.00
# Attendee 2 finished eating with hunger 16.00
# Attendee 0 finished talks with knowledge 7.15 and hunger 38.00
# Attendee 1 finished talks with knowledge 17.61 and hunger 20.00
# Attendee 2 finished talks with knowledge 8.87 and hunger 21.00
# Attendee 0 finished eating with hunger 26.00
# Attendee 1 finished eating with hunger 11.00
# Attendee 2 finished eating with hunger 15.00
# Attendee 0 finished talks with knowledge 7.22 and hunger 33.00
# Attendee 1 finished talks with knowledge 18.11 and hunger 17.00
# Attendee 2 finished talks with knowledge 9.02 and hunger 24.00
# Attendee 0 finished eating with hunger 24.00
# Attendee 1 finished eating with hunger 9.00
# Attendee 2 finished eating with hunger 12.00
# Attendee 0 finished talks with knowledge 7.29 and hunger 30.00
# Attendee 1 finished talks with knowledge 18.49 and hunger 18.00
# Attendee 2 finished talks with knowledge 9.17 and hunger 21.00
# Attendee 0 finished eating with hunger 23.00
# Attendee 1 finished eating with hunger 9.00
# Attendee 2 finished eating with hunger 9.00
# Attendee 0 finished talks with knowledge 7.42 and hunger 34.00
# Attendee 1 finished talks with knowledge 18.64 and hunger 17.00
# Attendee 2 finished talks with knowledge 9.17 and hunger 16.00
# Attendee 0 finished eating with hunger 31.00
# Attendee 1 finished eating with hunger 12.00
# Attendee 2 finished eating with hunger 12.00
# Attendee 0 finished talks with knowledge 7.55 and hunger 36.00
# Attendee 1 finished talks with knowledge 18.90 and hunger 21.00
# Attendee 2 finished talks with knowledge 9.70 and hunger 19.00
# Attendee 0 finished eating with hunger 26.00
# Attendee 1 finished eating with hunger 14.00
# Attendee 2 finished eating with hunger 14.00
# Attendee 0 finished talks with knowledge 7.64 and hunger 32.00
# Attendee 1 finished talks with knowledge 19.38 and hunger 21.00
# Attendee 2 finished talks with knowledge 9.96 and hunger 23.00
