# %%
import simpy
import random
import matplotlib.pyplot as plt

MAXSIMTIME = 100 # max idle time


class Job:
    def __init__(self, id, name, arrtime, duration):
        self.name = name
        self.tid = id
        self.arrtime = arrtime
        self.duration = duration
        self.responseTime = -1
        
    def __str__(self):
        return '%s at %d, length %d' %(self.name, self.arrtime, self.duration)

class Server:
    def __init__(self, env, strat = 'FIFO'):
        self.env = env
        self.strat = strat
        self.Jobs = list(())
        self.serversleeping = None

        ''' statistics '''
        self.waitingTime = 0
        self.idleTime = 0
        self.jobsDone = 0

        ''' register a new server process '''
        self.servproc = env.process(self.serve(env))

        
    def serve(self, env):
        while True:
            ''' do nothing, just change server to idle
              and then yield a wait event which takes infinite time
            '''
            if len( self.Jobs ) == 0 :
                self.serversleeping = env.process( self.waiting( self.env ))
                t1 = self.env.now
                yield self.serversleeping
                ''' accumulate the server idle time'''
                self.idleTime += self.env.now - t1
            else:
                ''' get the first job to be served'''
                # FIFO 
                j = self.Jobs.pop(0)

                ''' sum up the waiting time'''
                self.waitingTime += self.env.now - j.arrtime
                #######

                ''' yield an event for the job finish'''
                yield self.env.timeout( j.duration )

                ''' sum up the jobs done '''
                self.jobsDone += 1


                """ as the process is finished by CPU, it returns back to Terminal
                    therefore, server must wake up that Terminal which is sleeping """
                self.tlist[j.tid].waitrtproc.interrupt()

                if self.NJobDone == self.NJob:
                    """ reach threshold """
                    self.endTime = env.now
                    print("End at %.8f" % self.endTime)

                    acc = 0
                    for i in range(self.NTerminal):
                        self.tlist[i].done()
                        acc += self.tlist[i].NJobGen

                    self.avgResTime /= acc
                    return
    def waiting(self, env):
        try:
            print("Server is idle at %5.5f" % env.now)
            yield env.timeout(MAXSIMTIME)
        except simpy.Interrupt:
            print("A new job comes. Server waken up and works now at %5.5f" % env.now)

    def done(self):
        self.servproc.interrupt()


class Terminal:
    def __init__(self, tid, env, server, nrjobs, lam, mu):
        self.id = tid
        self.server = server
        self.nrjobs = nrjobs
        self.interarrivaltime = 1/lam;
        self.servicetime = 1/mu;
        self.servproc = env.process(self.generatejobs(env))


        
    def generatejobs(self, env):
        i = 1
        while True:
            try:
                """ yield an event for new job arrival """
                job_interarrival = random.exponential( self.interarrivaltime )
                yield env.timeout( job_interarrival )  # event: job's arrival


                """ generate service time and add job to the list """
                job_duration = random.exponential( self.servicetime )

                self.server.Jobs.append(
                    Job(self.id, "Job %s" % i, env.now, job_duration)
                )
                # print( 'Terminal: %d job %d: arrive at = %5.5f, length = %5.5f' %( self.id, i, env.now, job_duration ) )
                i += 1

                """ if server is idle, wake it up """
                if not self.server.serversleeping.triggered:
                    self.server.serversleeping.interrupt("Wake up, please.")

                self.isWaiting = True
                # print("Terminal %d start waiting" % self.id)
                self.waitrtproc = env.process(self.waiting(env))
                yield self.waitrtproc
                # print("Terminal %d stop waiting" % self.id)
            except:
                return
            
    def waiting(self, env):
        try:
            yield (env.timeout(MAXSIMTIME))
        except simpy.Interrupt:
            pass
    
    def done(self):
        self.servproc.interrupt()
        
def survey(njob, l, m):
    POPULATION = njob
    LAMBDA = l
    MU = m
    
    env = simpy.Environment()
    MyServer = Server( env, 'FIFO' )

    MyJobGenerator = Terminal( "1",env, MyServer, POPULATION, LAMBDA, MU )

    env.run()

survey(100, 5, 8)
# Out:
# No. Terminal:  1
# No. Jobs    :  1000
# Server is idle at 0.00000
# A new job comes. Server waken up and works now at 0.06566
# Server is idle at 0.59441
# A new job comes. Server waken up and works now at 0.65788
# Server is idle at 2.61781
# A new job comes. Server waken up and works now at 2.68218
# Server is idle at 3.32229
# A new job comes. Server waken up and works now at 3.38664
# Server is idle at 5.04810
# A new job comes. Server waken up and works now at 5.11132
# Server is idle at 5.91453
# A new job comes. Server waken up and works now at 5.98083
# Server is idle at 7.50524
# A new job comes. Server waken up and works now at 7.56803
# Server is idle at 9.33087
# A new job comes. Server waken up and works now at 9.39362
# Server is idle at 9.80634
# A new job comes. Server waken up and works now at 9.87227
# Server is idle at 10.20154
# A new job comes. Server waken up and works now at 10.26431
# Server is idle at 10.93012
# A new job comes. Server waken up and works now at 10.99329
# Server is idle at 11.39026
# A new job comes. Server waken up and works now at 11.45507
# Server is idle at 12.32045
# A new job comes. Server waken up and works now at 12.38475
# Server is idle at 12.83754
# A new job comes. Server waken up and works now at 12.90207
# Server is idle at 14.69245
# A new job comes. Server waken up and works now at 14.75582
# Server is idle at 16.27171
# A new job comes. Server waken up and works now at 16.33534
# Server is idle at 17.35268
# A new job comes. Server waken up and works now at 17.41781
# Server is idle at 18.26370
# A new job comes. Server waken up and works now at 18.32614
# Server is idle at 18.81623
# A new job comes. Server waken up and works now at 18.87960
# Server is idle at 19.19107
# A new job comes. Server waken up and works now at 19.25755
# Server is idle at 20.42726
# A new job comes. Server waken up and works now at 20.49014
# Server is idle at 21.56345
# A new job comes. Server waken up and works now at 21.62875
# Server is idle at 22.11980
# A new job comes. Server waken up and works now at 22.18475
# Server is idle at 23.07259
# A new job comes. Server waken up and works now at 23.13689
# Server is idle at 23.99089
# A new job comes. Server waken up and works now at 24.05708
# Server is idle at 24.63196
# A new job comes. Server waken up and works now at 24.69508
# Server is idle at 26.43460
# A new job comes. Server waken up and works now at 26.49828
# Server is idle at 27.33785
# A new job comes. Server waken up and works now at 27.40149
# Server is idle at 27.84100
# A new job comes. Server waken up and works now at 27.90511
# Server is idle at 28.54818
# A new job comes. Server waken up and works now at 28.61260
# Server is idle at 29.88393
# A new job comes. Server waken up and works now at 29.94834
# Server is idle at 30.32011
# A new job comes. Server waken up and works now at 30.38546
# Server is idle at 31.80915
# A new job comes. Server waken up and works now at 31.87523
# Server is idle at 33.48989
# A new job comes. Server waken up and works now at 33.55227
# Server is idle at 34.71081
# A new job comes. Server waken up and works now at 34.77710
# Server is idle at 35.04965
# A new job comes. Server waken up and works now at 35.11418
# Server is idle at 36.94693
# A new job comes. Server waken up and works now at 37.01244
# Server is idle at 38.94170
# A new job comes. Server waken up and works now at 39.00478
# Server is idle at 40.08187
# A new job comes. Server waken up and works now at 40.14652
# Server is idle at 41.13286
# A new job comes. Server waken up and works now at 41.19547
# Server is idle at 42.25870
# A new job comes. Server waken up and works now at 42.32360
# Server is idle at 42.98672
# A new job comes. Server waken up and works now at 43.05101
# Server is idle at 44.74925
# A new job comes. Server waken up and works now at 44.81352
# Server is idle at 45.86044
# A new job comes. Server waken up and works now at 45.92662
# Server is idle at 46.24420
# A new job comes. Server waken up and works now at 46.30765
# Server is idle at 46.78430
# A new job comes. Server waken up and works now at 46.84990
# Server is idle at 48.06852
# A new job comes. Server waken up and works now at 48.13514
# Server is idle at 48.58167
# A new job comes. Server waken up and works now at 48.64539
# Server is idle at 48.93074
# A new job comes. Server waken up and works now at 48.99426
# Server is idle at 50.04886
# A new job comes. Server waken up and works now at 50.11531
# Server is idle at 50.50037
# A new job comes. Server waken up and works now at 50.56646
# Server is idle at 52.20923
# A new job comes. Server waken up and works now at 52.27325
# Server is idle at 52.74793
# A new job comes. Server waken up and works now at 52.81400
# Server is idle at 53.21277
# A new job comes. Server waken up and works now at 53.27883
# Server is idle at 54.50666
# A new job comes. Server waken up and works now at 54.57183
# Server is idle at 55.50031
# A new job comes. Server waken up and works now at 55.56568
# Server is idle at 56.63426
# A new job comes. Server waken up and works now at 56.70088
# Server is idle at 57.05203
# A new job comes. Server waken up and works now at 57.11575
# Server is idle at 57.63913
# A new job comes. Server waken up and works now at 57.70414
# Server is idle at 58.41948
# A new job comes. Server waken up and works now at 58.48345
# Server is idle at 58.78516
# A new job comes. Server waken up and works now at 58.84769
# Server is idle at 59.71226
# A new job comes. Server waken up and works now at 59.77492
# Server is idle at 61.37542
# A new job comes. Server waken up and works now at 61.44167
# Server is idle at 61.78498
# A new job comes. Server waken up and works now at 61.84853
# Server is idle at 62.36140
# A new job comes. Server waken up and works now at 62.42754
# Server is idle at 63.13274
# A new job comes. Server waken up and works now at 63.19931
# Server is idle at 63.78918
# A new job comes. Server waken up and works now at 63.85257
# Server is idle at 64.50389
# A new job comes. Server waken up and works now at 64.56995
# Server is idle at 65.98972
# A new job comes. Server waken up and works now at 66.05610
# Server is idle at 67.95026
# A new job comes. Server waken up and works now at 68.01551
# Server is idle at 69.29401
# A new job comes. Server waken up and works now at 69.36019
# Server is idle at 69.76905
# A new job comes. Server waken up and works now at 69.83322
# Server is idle at 70.42275
# A new job comes. Server waken up and works now at 70.48776
# Server is idle at 71.50799
# A new job comes. Server waken up and works now at 71.57374
# Server is idle at 71.89750
# A new job comes. Server waken up and works now at 71.96367
# Server is idle at 73.23555
# A new job comes. Server waken up and works now at 73.30068
# Server is idle at 74.48266
# A new job comes. Server waken up and works now at 74.54752
# Server is idle at 75.22850
# A new job comes. Server waken up and works now at 75.29493
# Server is idle at 75.68706
# A new job comes. Server waken up and works now at 75.74982
# Server is idle at 76.11529
# A new job comes. Server waken up and works now at 76.17984
# Server is idle at 76.91272
# A new job comes. Server waken up and works now at 76.97701
# Server is idle at 77.66603
# A new job comes. Server waken up and works now at 77.72867
# Server is idle at 79.48266
# A new job comes. Server waken up and works now at 79.54875
# Server is idle at 80.27276
# A new job comes. Server waken up and works now at 80.33857
# Server is idle at 81.48354
# A new job comes. Server waken up and works now at 81.54937
# Server is idle at 81.88059
# A new job comes. Server waken up and works now at 81.94705
# Server is idle at 82.47622
# A new job comes. Server waken up and works now at 82.53881
# Server is idle at 84.01519
# A new job comes. Server waken up and works now at 84.07804
# Server is idle at 84.52395
# A new job comes. Server waken up and works now at 84.58886
# Server is idle at 85.89216
# A new job comes. Server waken up and works now at 85.95834
# Server is idle at 87.87399
# A new job comes. Server waken up and works now at 87.93764
# Server is idle at 88.34464
# A new job comes. Server waken up and works now at 88.40723
# Server is idle at 88.74920
# A new job comes. Server waken up and works now at 88.81350
# Server is idle at 89.15429
# A new job comes. Server waken up and works now at 89.22047
# Server is idle at 89.51663
# A new job comes. Server waken up and works now at 89.58182
# Server is idle at 90.44041
# A new job comes. Server waken up and works now at 90.50305
# Server is idle at 91.34219
# A new job comes. Server waken up and works now at 91.40458
# Server is idle at 93.01635
# A new job comes. Server waken up and works now at 93.08119
# Server is idle at 94.24849
# A new job comes. Server waken up and works now at 94.31097
# Server is idle at 94.73657
# A new job comes. Server waken up and works now at 94.80171
# Server is idle at 95.52308
# A new job comes. Server waken up and works now at 95.58663
# Server is idle at 97.07719
# A new job comes. Server waken up and works now at 97.14004
# Server is idle at 97.99129
# A new job comes. Server waken up and works now at 98.05516
# Server is idle at 98.37587
# A new job comes. Server waken up and works now at 98.44222
# Server is idle at 99.67128
# A new job comes. Server waken up and works now at 99.73776
# Server is idle at 101.30129
# A new job comes. Server waken up and works now at 101.36452
# Server is idle at 101.65324
# A new job comes. Server waken up and works now at 101.71937
# Server is idle at 102.46718
# A new job comes. Server waken up and works now at 102.53260
# Server is idle at 104.27083
# A new job comes. Server waken up and works now at 104.33455
# Server is idle at 105.48229
# A new job comes. Server waken up and works now at 105.54823
# Server is idle at 106.19549
# A new job comes. Server waken up and works now at 106.25882
# Server is idle at 106.60790
# A new job comes. Server waken up and works now at 106.67381
# Server is idle at 107.41212
# A new job comes. Server waken up and works now at 107.47859
# Server is idle at 107.85427
# A new job comes. Server waken up and works now at 107.91706
# Server is idle at 109.38533
# A new job comes. Server waken up and works now at 109.45028
# Server is idle at 109.84210
# A new job comes. Server waken up and works now at 109.90838
# Server is idle at 110.59867
# A new job comes. Server waken up and works now at 110.66373
# Server is idle at 112.26217
# A new job comes. Server waken up and works now at 112.32728
# Server is idle at 112.68321
# A new job comes. Server waken up and works now at 112.74828
# Server is idle at 113.05670
# A new job comes. Server waken up and works now at 113.12035
# Server is idle at 114.78102
# A new job comes. Server waken up and works now at 114.84545
# Server is idle at 116.60698
# A new job comes. Server waken up and works now at 116.67333
# Server is idle at 117.25362
# A new job comes. Server waken up and works now at 117.31733
# Server is idle at 118.12069
# A new job comes. Server waken up and works now at 118.18351
# Server is idle at 118.85813
# A new job comes. Server waken up and works now at 118.92431
# Server is idle at 119.58311
# A new job comes. Server waken up and works now at 119.64549
# Server is idle at 120.33484
# A new job comes. Server waken up and works now at 120.39758
# Server is idle at 121.38399
# A new job comes. Server waken up and works now at 121.44963
# Server is idle at 122.52641
# A new job comes. Server waken up and works now at 122.59189
# Server is idle at 123.22695
# A new job comes. Server waken up and works now at 123.29341
# Server is idle at 124.74141
# A new job comes. Server waken up and works now at 124.80642
# Server is idle at 125.37116
# A new job comes. Server waken up and works now at 125.43556
# Server is idle at 125.84264
# A new job comes. Server waken up and works now at 125.90772
# Server is idle at 126.55302
# A new job comes. Server waken up and works now at 126.61585
# Server is idle at 127.26028
# A new job comes. Server waken up and works now at 127.32463
# Server is idle at 127.87015
# A new job comes. Server waken up and works now at 127.93515
# Server is idle at 128.22933
# A new job comes. Server waken up and works now at 128.29368
# Server is idle at 128.58322
# A new job comes. Server waken up and works now at 128.64831
# Server is idle at 129.12412
# A new job comes. Server waken up and works now at 129.18823
# Server is idle at 130.05763
# A new job comes. Server waken up and works now at 130.12169
# Server is idle at 130.43543
# A new job comes. Server waken up and works now at 130.49999
# Server is idle at 130.81376
# A new job comes. Server waken up and works now at 130.87617
# Server is idle at 132.77939
# A new job comes. Server waken up and works now at 132.84267
# Server is idle at 134.42238
# A new job comes. Server waken up and works now at 134.48650
# Server is idle at 134.80932
# A new job comes. Server waken up and works now at 134.87482
# Server is idle at 135.35984
# A new job comes. Server waken up and works now at 135.42400
# Server is idle at 136.05402
# A new job comes. Server waken up and works now at 136.11904
# Server is idle at 136.95088
# A new job comes. Server waken up and works now at 137.01354
# Server is idle at 138.39149
# A new job comes. Server waken up and works now at 138.45711
# Server is idle at 138.92137
# A new job comes. Server waken up and works now at 138.98613
# Server is idle at 140.04850
# A new job comes. Server waken up and works now at 140.11368
# Server is idle at 140.49509
# A new job comes. Server waken up and works now at 140.55992
# Server is idle at 140.88913
# A new job comes. Server waken up and works now at 140.95521
# Server is idle at 142.49657
# A new job comes. Server waken up and works now at 142.55972
# Server is idle at 143.01886
# A new job comes. Server waken up and works now at 143.08220
# Server is idle at 144.92301
# A new job comes. Server waken up and works now at 144.98812
# Server is idle at 146.73708
# A new job comes. Server waken up and works now at 146.80195
# Server is idle at 147.52858
# A new job comes. Server waken up and works now at 147.59143
# Server is idle at 147.92999
# A new job comes. Server waken up and works now at 147.99584
# Server is idle at 148.61988
# A new job comes. Server waken up and works now at 148.68304
# Server is idle at 149.69367
# A new job comes. Server waken up and works now at 149.75698
# Server is idle at 150.47223
# A new job comes. Server waken up and works now at 150.53537
# Server is idle at 151.32667
# A new job comes. Server waken up and works now at 151.39117
# Server is idle at 152.95236
# A new job comes. Server waken up and works now at 153.01578
# Server is idle at 154.54070
# A new job comes. Server waken up and works now at 154.60323
# Server is idle at 155.05520
# A new job comes. Server waken up and works now at 155.11893
# Server is idle at 155.53434
# A new job comes. Server waken up and works now at 155.59919
# Server is idle at 156.03260
# A new job comes. Server waken up and works now at 156.09687
# Server is idle at 157.35566
# A new job comes. Server waken up and works now at 157.41916
# Server is idle at 159.11252
# A new job comes. Server waken up and works now at 159.17656
# Server is idle at 160.41800
# A new job comes. Server waken up and works now at 160.48234
# Server is idle at 161.47293
# A new job comes. Server waken up and works now at 161.53727
# Server is idle at 162.00440
# A new job comes. Server waken up and works now at 162.06754
# Server is idle at 162.75409
# A new job comes. Server waken up and works now at 162.81707
# Server is idle at 163.90426
# A new job comes. Server waken up and works now at 163.97067
# Server is idle at 165.36433
# A new job comes. Server waken up and works now at 165.42748
# Server is idle at 165.96735
# A new job comes. Server waken up and works now at 166.03078
# Server is idle at 167.78417
# A new job comes. Server waken up and works now at 167.84830
# Server is idle at 168.59301
# A new job comes. Server waken up and works now at 168.65540
# Server is idle at 169.57450
# A new job comes. Server waken up and works now at 169.63828
# Server is idle at 170.38884
# A new job comes. Server waken up and works now at 170.45265
# Server is idle at 172.04614
# A new job comes. Server waken up and works now at 172.11230
# Server is idle at 173.55679
# A new job comes. Server waken up and works now at 173.62152
# Server is idle at 174.02929
# A new job comes. Server waken up and works now at 174.09357
# Server is idle at 174.36767
# A new job comes. Server waken up and works now at 174.43421
# Server is idle at 174.85799
# A new job comes. Server waken up and works now at 174.92039
# Server is idle at 175.64945
# A new job comes. Server waken up and works now at 175.71248
# Server is idle at 176.41435
# A new job comes. Server waken up and works now at 176.47770
# Server is idle at 176.97699
# A new job comes. Server waken up and works now at 177.03959
# Server is idle at 178.56549
# A new job comes. Server waken up and works now at 178.63199
# Server is idle at 179.02903
# A new job comes. Server waken up and works now at 179.09553
# Server is idle at 179.54954
# A new job comes. Server waken up and works now at 179.61246
# Server is idle at 179.93982
# A new job comes. Server waken up and works now at 180.00602
# Server is idle at 180.97374
# A new job comes. Server waken up and works now at 181.03834
# Server is idle at 181.56726
# A new job comes. Server waken up and works now at 181.63251
# Server is idle at 182.61206
# A new job comes. Server waken up and works now at 182.67682
# Server is idle at 183.63639
# A new job comes. Server waken up and works now at 183.70222
# Server is idle at 184.27561
# A new job comes. Server waken up and works now at 184.34177
# Server is idle at 185.27616
# A new job comes. Server waken up and works now at 185.33858
# Server is idle at 186.73956
# A new job comes. Server waken up and works now at 186.80441
# Server is idle at 188.68112
# A new job comes. Server waken up and works now at 188.74589
# Server is idle at 190.53679
# A new job comes. Server waken up and works now at 190.60023
# Server is idle at 191.32074
# A new job comes. Server waken up and works now at 191.38668
# Server is idle at 193.06056
# A new job comes. Server waken up and works now at 193.12299
# Server is idle at 193.76904
# A new job comes. Server waken up and works now at 193.83467
# Server is idle at 194.32637
# A new job comes. Server waken up and works now at 194.39190
# Server is idle at 195.12239
# A new job comes. Server waken up and works now at 195.18511
# Server is idle at 196.12317
# A new job comes. Server waken up and works now at 196.18628
# Server is idle at 197.31416
# A new job comes. Server waken up and works now at 197.38050
# Server is idle at 198.66988
# A new job comes. Server waken up and works now at 198.73313
# Server is idle at 199.26722
# A new job comes. Server waken up and works now at 199.33138
# Server is idle at 200.09557
# A new job comes. Server waken up and works now at 200.15985
# Server is idle at 200.71023
# A new job comes. Server waken up and works now at 200.77579
# Server is idle at 201.70197
# A new job comes. Server waken up and works now at 201.76582
# Server is idle at 203.58039
# A new job comes. Server waken up and works now at 203.64364
# Server is idle at 204.35370
# A new job comes. Server waken up and works now at 204.42013
# Server is idle at 204.76279
# A new job comes. Server waken up and works now at 204.82660
# Server is idle at 205.50303
# A new job comes. Server waken up and works now at 205.56664
# Server is idle at 207.16912
# A new job comes. Server waken up and works now at 207.23259
# Server is idle at 208.27762
# A new job comes. Server waken up and works now at 208.34244
# Server is idle at 208.75957
# A new job comes. Server waken up and works now at 208.82522
# Server is idle at 210.08119
# A new job comes. Server waken up and works now at 210.14387
# Server is idle at 210.90783
# A new job comes. Server waken up and works now at 210.97215
# Server is idle at 211.42493
# A new job comes. Server waken up and works now at 211.49128
# Server is idle at 211.95221
# A new job comes. Server waken up and works now at 212.01860
# Server is idle at 213.18537
# A new job comes. Server waken up and works now at 213.24997
# Server is idle at 214.21187
# A new job comes. Server waken up and works now at 214.27570
# Server is idle at 214.67795
# A new job comes. Server waken up and works now at 214.74129
# Server is idle at 215.04281
# A new job comes. Server waken up and works now at 215.10544
# Server is idle at 215.44174
# A new job comes. Server waken up and works now at 215.50581
# Server is idle at 216.27507
# A new job comes. Server waken up and works now at 216.34096
# Server is idle at 216.85325
# A new job comes. Server waken up and works now at 216.91873
# Server is idle at 217.56655
# A new job comes. Server waken up and works now at 217.63104
# Server is idle at 219.36097
# A new job comes. Server waken up and works now at 219.42716
# Server is idle at 219.97419
# A new job comes. Server waken up and works now at 220.03906
# Server is idle at 220.33328
# A new job comes. Server waken up and works now at 220.39671
# Server is idle at 222.14968
# A new job comes. Server waken up and works now at 222.21593
# Server is idle at 223.26592
# A new job comes. Server waken up and works now at 223.32893
# Server is idle at 224.56959
# A new job comes. Server waken up and works now at 224.63488
# Server is idle at 225.12795
# A new job comes. Server waken up and works now at 225.19118
# Server is idle at 226.22087
# A new job comes. Server waken up and works now at 226.28505
# Server is idle at 227.68766
# A new job comes. Server waken up and works now at 227.75046
# Server is idle at 229.56013
# A new job comes. Server waken up and works now at 229.62674
# Server is idle at 230.36325
# A new job comes. Server waken up and works now at 230.42873
# Server is idle at 231.06838
# A new job comes. Server waken up and works now at 231.13154
# Server is idle at 232.10786
# A new job comes. Server waken up and works now at 232.17437
# Server is idle at 233.24833
# A new job comes. Server waken up and works now at 233.31378
# Server is idle at 233.98655
# A new job comes. Server waken up and works now at 234.05114
# Server is idle at 235.76411
# A new job comes. Server waken up and works now at 235.82828
# Server is idle at 237.54387
# A new job comes. Server waken up and works now at 237.61014
# Server is idle at 238.19471
# A new job comes. Server waken up and works now at 238.25869
# Server is idle at 239.42715
# A new job comes. Server waken up and works now at 239.49200
# Server is idle at 239.78107
# A new job comes. Server waken up and works now at 239.84443
# Server is idle at 240.46658
# A new job comes. Server waken up and works now at 240.52978
# Server is idle at 241.05183
# A new job comes. Server waken up and works now at 241.11608
# Server is idle at 242.55574
# A new job comes. Server waken up and works now at 242.61828
# Server is idle at 242.95005
# A new job comes. Server waken up and works now at 243.01467
# Server is idle at 243.56434
# A new job comes. Server waken up and works now at 243.62750
# Server is idle at 244.00469
# A new job comes. Server waken up and works now at 244.06800
# Server is idle at 245.65176
# A new job comes. Server waken up and works now at 245.71508
# Server is idle at 246.25079
# A new job comes. Server waken up and works now at 246.31604
# Server is idle at 247.18158
# A new job comes. Server waken up and works now at 247.24543
# Server is idle at 247.62105
# A new job comes. Server waken up and works now at 247.68488
# Server is idle at 248.03520
# A new job comes. Server waken up and works now at 248.10092
# Server is idle at 248.54659
# A new job comes. Server waken up and works now at 248.61316
# Server is idle at 249.58906
# A new job comes. Server waken up and works now at 249.65153
# Server is idle at 250.19015
# A new job comes. Server waken up and works now at 250.25429
# Server is idle at 251.34835
# A new job comes. Server waken up and works now at 251.41200
# Server is idle at 251.82729
# A new job comes. Server waken up and works now at 251.89251
# Server is idle at 252.89192
# A new job comes. Server waken up and works now at 252.95543
# Server is idle at 253.35561
# A new job comes. Server waken up and works now at 253.41819
# Server is idle at 255.19387
# A new job comes. Server waken up and works now at 255.25664
# Server is idle at 255.90236
# A new job comes. Server waken up and works now at 255.96794
# Server is idle at 256.24926
# A new job comes. Server waken up and works now at 256.31483
# Server is idle at 257.00706
# A new job comes. Server waken up and works now at 257.06955
# Server is idle at 258.20959
# A new job comes. Server waken up and works now at 258.27212
# Server is idle at 259.08284
# A new job comes. Server waken up and works now at 259.14664
# Server is idle at 259.44734
# A new job comes. Server waken up and works now at 259.51233
# Server is idle at 260.81524
# A new job comes. Server waken up and works now at 260.88149
# Server is idle at 262.07955
# A new job comes. Server waken up and works now at 262.14381
# Server is idle at 263.10462
# A new job comes. Server waken up and works now at 263.16956
# Server is idle at 263.44807
# A new job comes. Server waken up and works now at 263.51268
# Server is idle at 264.36104
# A new job comes. Server waken up and works now at 264.42474
# Server is idle at 265.20422
# A new job comes. Server waken up and works now at 265.26674
# Server is idle at 266.45528
# A new job comes. Server waken up and works now at 266.52067
# Server is idle at 266.79782
# A new job comes. Server waken up and works now at 266.86034
# Server is idle at 267.20702
# A new job comes. Server waken up and works now at 267.27127
# Server is idle at 268.86372
# A new job comes. Server waken up and works now at 268.92869
# Server is idle at 269.50450
# A new job comes. Server waken up and works now at 269.56852
# Server is idle at 270.58156
# A new job comes. Server waken up and works now at 270.64537
# Server is idle at 271.41534
# A new job comes. Server waken up and works now at 271.48045
# Server is idle at 271.86613
# A new job comes. Server waken up and works now at 271.93138
# Server is idle at 273.62621
# A new job comes. Server waken up and works now at 273.68960
# Server is idle at 274.73987
# A new job comes. Server waken up and works now at 274.80436
# Server is idle at 275.72586
# A new job comes. Server waken up and works now at 275.78879
# Server is idle at 276.06985
# A new job comes. Server waken up and works now at 276.13501
# Server is idle at 276.78087
# A new job comes. Server waken up and works now at 276.84721
# Server is idle at 278.04992
# A new job comes. Server waken up and works now at 278.11403
# Server is idle at 278.93824
# A new job comes. Server waken up and works now at 279.00424
# Server is idle at 279.31971
# A new job comes. Server waken up and works now at 279.38254
# Server is idle at 280.68827
# A new job comes. Server waken up and works now at 280.75235
# Server is idle at 282.19753
# A new job comes. Server waken up and works now at 282.26184
# Server is idle at 282.63274
# A new job comes. Server waken up and works now at 282.69747
# Server is idle at 284.21169
# A new job comes. Server waken up and works now at 284.27792
# Server is idle at 284.91532
# A new job comes. Server waken up and works now at 284.97822
# Server is idle at 286.60804
# A new job comes. Server waken up and works now at 286.67182
# Server is idle at 287.04864
# A new job comes. Server waken up and works now at 287.11437
# Server is idle at 287.92846
# A new job comes. Server waken up and works now at 287.99445
# Server is idle at 288.44999
# A new job comes. Server waken up and works now at 288.51275
# Server is idle at 288.87369
# A new job comes. Server waken up and works now at 288.93795
# Server is idle at 289.95205
# A new job comes. Server waken up and works now at 290.01865
# Server is idle at 290.88485
# A new job comes. Server waken up and works now at 290.95110
# Server is idle at 291.63520
# A new job comes. Server waken up and works now at 291.69937
# Server is idle at 292.10264
# A new job comes. Server waken up and works now at 292.16582
# Server is idle at 292.74535
# A new job comes. Server waken up and works now at 292.81020
# Server is idle at 293.39736
# A new job comes. Server waken up and works now at 293.46101
# Server is idle at 295.00796
# A new job comes. Server waken up and works now at 295.07201
# Server is idle at 295.38990
# A new job comes. Server waken up and works now at 295.45558
# Server is idle at 295.92721
# A new job comes. Server waken up and works now at 295.99054
# Server is idle at 296.87857
# A new job comes. Server waken up and works now at 296.94291
# Server is idle at 298.41189
# A new job comes. Server waken up and works now at 298.47831
# Server is idle at 299.50445
# A new job comes. Server waken up and works now at 299.56782
# Server is idle at 300.02488
# A new job comes. Server waken up and works now at 300.08804
# Server is idle at 300.37721
# A new job comes. Server waken up and works now at 300.44290
# Server is idle at 301.03298
# A new job comes. Server waken up and works now at 301.09739
# Server is idle at 302.80654
# A new job comes. Server waken up and works now at 302.87220
# Server is idle at 304.79520
# A new job comes. Server waken up and works now at 304.86021
# Server is idle at 306.23187
# A new job comes. Server waken up and works now at 306.29628
# Server is idle at 307.50880
# A new job comes. Server waken up and works now at 307.57343
# Server is idle at 307.96773
# A new job comes. Server waken up and works now at 308.03082
# Server is idle at 309.85839
# A new job comes. Server waken up and works now at 309.92133
# Server is idle at 310.32859
# A new job comes. Server waken up and works now at 310.39330
# Server is idle at 311.25029
# A new job comes. Server waken up and works now at 311.31388
# Server is idle at 312.26685
# A new job comes. Server waken up and works now at 312.33272
# Server is idle at 312.68174
# A new job comes. Server waken up and works now at 312.74702
# Server is idle at 313.77586
# A new job comes. Server waken up and works now at 313.83857
# Server is idle at 314.24476
# A new job comes. Server waken up and works now at 314.31020
# Server is idle at 315.69174
# A new job comes. Server waken up and works now at 315.75725
# Server is idle at 316.99786
# A new job comes. Server waken up and works now at 317.06301
# Server is idle at 317.92519
# A new job comes. Server waken up and works now at 317.98782
# Server is idle at 318.91917
# A new job comes. Server waken up and works now at 318.98502
# Server is idle at 319.29910
# A new job comes. Server waken up and works now at 319.36427
# Server is idle at 320.33104
# A new job comes. Server waken up and works now at 320.39437
# Server is idle at 320.67132
# A new job comes. Server waken up and works now at 320.73407
# Server is idle at 321.70940
# A new job comes. Server waken up and works now at 321.77369
# Server is idle at 323.30622
# A new job comes. Server waken up and works now at 323.37101
# Server is idle at 323.73997
# A new job comes. Server waken up and works now at 323.80624
# Server is idle at 324.18421
# A new job comes. Server waken up and works now at 324.24723
# Server is idle at 326.04498
# A new job comes. Server waken up and works now at 326.10969
# Server is idle at 326.72299
# A new job comes. Server waken up and works now at 326.78922
# Server is idle at 328.59413
# A new job comes. Server waken up and works now at 328.66024
# Server is idle at 329.00674
# A new job comes. Server waken up and works now at 329.07287
# Server is idle at 329.39742
# A new job comes. Server waken up and works now at 329.46319
# Server is idle at 330.81076
# A new job comes. Server waken up and works now at 330.87368
# Server is idle at 331.48209
# A new job comes. Server waken up and works now at 331.54585
# Server is idle at 332.54165
# A new job comes. Server waken up and works now at 332.60546
# Server is idle at 334.51250
# A new job comes. Server waken up and works now at 334.57746
# Server is idle at 334.95422
# A new job comes. Server waken up and works now at 335.01771
# Server is idle at 335.36631
# A new job comes. Server waken up and works now at 335.43164
# Server is idle at 335.87206
# A new job comes. Server waken up and works now at 335.93593
# Server is idle at 336.50719
# A new job comes. Server waken up and works now at 336.57296
# Server is idle at 337.24046
# A new job comes. Server waken up and works now at 337.30300
# Server is idle at 338.90057
# A new job comes. Server waken up and works now at 338.96592
# Server is idle at 340.62246
# A new job comes. Server waken up and works now at 340.68561
# Server is idle at 342.11487
# A new job comes. Server waken up and works now at 342.17833
# Server is idle at 342.84056
# A new job comes. Server waken up and works now at 342.90609
# Server is idle at 344.85552
# A new job comes. Server waken up and works now at 344.91892
# Server is idle at 346.41722
# A new job comes. Server waken up and works now at 346.48209
# Server is idle at 347.04237
# A new job comes. Server waken up and works now at 347.10874
# Server is idle at 348.24322
# A new job comes. Server waken up and works now at 348.30772
# Server is idle at 348.65159
# A new job comes. Server waken up and works now at 348.71722
# Server is idle at 349.99174
# A new job comes. Server waken up and works now at 350.05633
# Server is idle at 351.07751
# A new job comes. Server waken up and works now at 351.14072
# Server is idle at 351.65695
# A new job comes. Server waken up and works now at 351.72150
# Server is idle at 352.00639
# A new job comes. Server waken up and works now at 352.07260
# Server is idle at 353.92116
# A new job comes. Server waken up and works now at 353.98446
# Server is idle at 354.29661
# A new job comes. Server waken up and works now at 354.36015
# Server is idle at 356.10743
# A new job comes. Server waken up and works now at 356.17337
# Server is idle at 356.47457
# A new job comes. Server waken up and works now at 356.53875
# Server is idle at 356.97167
# A new job comes. Server waken up and works now at 357.03680
# Server is idle at 357.42560
# A new job comes. Server waken up and works now at 357.49093
# Server is idle at 359.47765
# A new job comes. Server waken up and works now at 359.54301
# Server is idle at 360.88287
# A new job comes. Server waken up and works now at 360.94899
# Server is idle at 362.13884
# A new job comes. Server waken up and works now at 362.20446
# Server is idle at 363.13556
# A new job comes. Server waken up and works now at 363.20006
# Server is idle at 363.54048
# A new job comes. Server waken up and works now at 363.60602
# Server is idle at 365.54971
# A new job comes. Server waken up and works now at 365.61526
# Server is idle at 365.92001
# A new job comes. Server waken up and works now at 365.98394
# Server is idle at 366.51806
# A new job comes. Server waken up and works now at 366.58187
# Server is idle at 367.17690
# A new job comes. Server waken up and works now at 367.24178
# Server is idle at 367.52988
# A new job comes. Server waken up and works now at 367.59584
# Server is idle at 369.12965
# A new job comes. Server waken up and works now at 369.19578
# Server is idle at 370.92722
# A new job comes. Server waken up and works now at 370.99136
# Server is idle at 371.63376
# A new job comes. Server waken up and works now at 371.69633
# Server is idle at 372.44665
# A new job comes. Server waken up and works now at 372.51152
# Server is idle at 374.29308
# A new job comes. Server waken up and works now at 374.35585
# Server is idle at 374.80591
# A new job comes. Server waken up and works now at 374.87223
# Server is idle at 375.17142
# A new job comes. Server waken up and works now at 375.23535
# Server is idle at 375.72202
# A new job comes. Server waken up and works now at 375.78692
# Server is idle at 377.24690
# A new job comes. Server waken up and works now at 377.31085
# Server is idle at 378.12970
# A new job comes. Server waken up and works now at 378.19327
# Server is idle at 378.82141
# A new job comes. Server waken up and works now at 378.88755
# Server is idle at 379.69677
# A new job comes. Server waken up and works now at 379.76097
# Server is idle at 380.26528
# A new job comes. Server waken up and works now at 380.33029
# Server is idle at 380.70716
# A new job comes. Server waken up and works now at 380.77348
# Server is idle at 381.61878
# A new job comes. Server waken up and works now at 381.68244
# Server is idle at 382.22353
# A new job comes. Server waken up and works now at 382.28626
# Server is idle at 382.92406
# A new job comes. Server waken up and works now at 382.98910
# Server is idle at 383.30702
# A new job comes. Server waken up and works now at 383.37263
# Server is idle at 385.25779
# A new job comes. Server waken up and works now at 385.32356
# Server is idle at 386.91716
# A new job comes. Server waken up and works now at 386.98233
# Server is idle at 387.47628
# A new job comes. Server waken up and works now at 387.54197
# Server is idle at 388.54008
# A new job comes. Server waken up and works now at 388.60259
# Server is idle at 389.68458
# A new job comes. Server waken up and works now at 389.74742
# Server is idle at 390.52451
# A new job comes. Server waken up and works now at 390.59075
# Server is idle at 391.22629
# A new job comes. Server waken up and works now at 391.29220
# Server is idle at 391.71491
# A new job comes. Server waken up and works now at 391.77756
# Server is idle at 392.08762
# A new job comes. Server waken up and works now at 392.15267
# Server is idle at 392.62293
# A new job comes. Server waken up and works now at 392.68765
# Server is idle at 393.71197
# A new job comes. Server waken up and works now at 393.77855
# Server is idle at 394.06968
# A new job comes. Server waken up and works now at 394.13388
# Server is idle at 395.80291
# A new job comes. Server waken up and works now at 395.86656
# Server is idle at 396.29812
# A new job comes. Server waken up and works now at 396.36110
# Server is idle at 397.05607
# A new job comes. Server waken up and works now at 397.12216
# Server is idle at 397.54470
# A new job comes. Server waken up and works now at 397.61011
# Server is idle at 399.56144
# A new job comes. Server waken up and works now at 399.62571
# Server is idle at 400.55932
# A new job comes. Server waken up and works now at 400.62359
# Server is idle at 401.18242
# A new job comes. Server waken up and works now at 401.24604
# Server is idle at 401.52165
# A new job comes. Server waken up and works now at 401.58642
# Server is idle at 402.96094
# A new job comes. Server waken up and works now at 403.02389
# Server is idle at 403.36145
# A new job comes. Server waken up and works now at 403.42805
# Server is idle at 403.96661
# A new job comes. Server waken up and works now at 404.03243
# Server is idle at 404.51038
# A new job comes. Server waken up and works now at 404.57600
# Server is idle at 405.38166
# A new job comes. Server waken up and works now at 405.44739
# Server is idle at 406.24203
# A new job comes. Server waken up and works now at 406.30721
# Server is idle at 407.05374
# A new job comes. Server waken up and works now at 407.11798
# Server is idle at 407.47770
# A new job comes. Server waken up and works now at 407.54148
# Server is idle at 408.86876
# A new job comes. Server waken up and works now at 408.93521
# Server is idle at 409.24046
# A new job comes. Server waken up and works now at 409.30292
# Server is idle at 409.88192
# A new job comes. Server waken up and works now at 409.94623
# Server is idle at 411.37078
# A new job comes. Server waken up and works now at 411.43406
# Server is idle at 411.97183
# A new job comes. Server waken up and works now at 412.03834
# Server is idle at 412.83689
# A new job comes. Server waken up and works now at 412.90188
# Server is idle at 413.72308
# A new job comes. Server waken up and works now at 413.78749
# Server is idle at 414.90324
# A new job comes. Server waken up and works now at 414.96779
# Server is idle at 415.55824
# A new job comes. Server waken up and works now at 415.62258
# Server is idle at 416.12001
# A new job comes. Server waken up and works now at 416.18527
# Server is idle at 417.77284
# A new job comes. Server waken up and works now at 417.83626
# Server is idle at 418.26915
# A new job comes. Server waken up and works now at 418.33181
# Server is idle at 418.61719
# A new job comes. Server waken up and works now at 418.68287
# Server is idle at 420.37059
# A new job comes. Server waken up and works now at 420.43485
# Server is idle at 420.98888
# A new job comes. Server waken up and works now at 421.05283
# Server is idle at 421.41520
# A new job comes. Server waken up and works now at 421.48109
# Server is idle at 422.01570
# A new job comes. Server waken up and works now at 422.08090
# Server is idle at 422.95116
# A new job comes. Server waken up and works now at 423.01600
# Server is idle at 423.57210
# A new job comes. Server waken up and works now at 423.63461
# Server is idle at 424.58670
# A new job comes. Server waken up and works now at 424.65293
# Server is idle at 426.01814
# A new job comes. Server waken up and works now at 426.08327
# Server is idle at 427.62387
# A new job comes. Server waken up and works now at 427.68648
# Server is idle at 429.10583
# A new job comes. Server waken up and works now at 429.17025
# Server is idle at 429.84931
# A new job comes. Server waken up and works now at 429.91522
# Server is idle at 430.59386
# A new job comes. Server waken up and works now at 430.65922
# Server is idle at 430.96972
# A new job comes. Server waken up and works now at 431.03327
# Server is idle at 431.47226
# A new job comes. Server waken up and works now at 431.53606
# Server is idle at 433.32062
# A new job comes. Server waken up and works now at 433.38713
# Server is idle at 434.30088
# A new job comes. Server waken up and works now at 434.36491
# Server is idle at 434.64681
# A new job comes. Server waken up and works now at 434.71024
# Server is idle at 434.98885
# A new job comes. Server waken up and works now at 435.05299
# Server is idle at 436.97582
# A new job comes. Server waken up and works now at 437.04089
# Server is idle at 437.79528
# A new job comes. Server waken up and works now at 437.86022
# Server is idle at 439.45509
# A new job comes. Server waken up and works now at 439.51765
# Server is idle at 439.91011
# A new job comes. Server waken up and works now at 439.97650
# Server is idle at 440.47667
# A new job comes. Server waken up and works now at 440.53942
# Server is idle at 441.89155
# A new job comes. Server waken up and works now at 441.95455
# Server is idle at 442.50257
# A new job comes. Server waken up and works now at 442.56692
# Server is idle at 442.95122
# A new job comes. Server waken up and works now at 443.01788
# Server is idle at 443.37671
# A new job comes. Server waken up and works now at 443.44011
# Server is idle at 444.77106
# A new job comes. Server waken up and works now at 444.83414
# Server is idle at 445.19506
# A new job comes. Server waken up and works now at 445.25979
# Server is idle at 445.71448
# A new job comes. Server waken up and works now at 445.78080
# Server is idle at 446.27354
# A new job comes. Server waken up and works now at 446.33963
# Server is idle at 446.64409
# A new job comes. Server waken up and works now at 446.71024
# Server is idle at 447.91334
# A new job comes. Server waken up and works now at 447.97668
# Server is idle at 449.82355
# A new job comes. Server waken up and works now at 449.88826
# Server is idle at 451.13352
# A new job comes. Server waken up and works now at 451.19673
# Server is idle at 452.69935
# A new job comes. Server waken up and works now at 452.76390
# Server is idle at 454.64915
# A new job comes. Server waken up and works now at 454.71299
# Server is idle at 455.69070
# A new job comes. Server waken up and works now at 455.75424
# Server is idle at 456.61792
# A new job comes. Server waken up and works now at 456.68457
# Server is idle at 456.97877
# A new job comes. Server waken up and works now at 457.04236
# Server is idle at 458.41949
# A new job comes. Server waken up and works now at 458.48373
# Server is idle at 459.19283
# A new job comes. Server waken up and works now at 459.25764
# Server is idle at 460.63099
# A new job comes. Server waken up and works now at 460.69518
# Server is idle at 461.38025
# A new job comes. Server waken up and works now at 461.44465
# Server is idle at 462.75000
# A new job comes. Server waken up and works now at 462.81335
# Server is idle at 464.10991
# A new job comes. Server waken up and works now at 464.17574
# Server is idle at 465.73227
# A new job comes. Server waken up and works now at 465.79592
# Server is idle at 466.72969
# A new job comes. Server waken up and works now at 466.79225
# Server is idle at 467.80061
# A new job comes. Server waken up and works now at 467.86359
# Server is idle at 468.42430
# A new job comes. Server waken up and works now at 468.48983
# Server is idle at 468.78030
# A new job comes. Server waken up and works now at 468.84669
# Server is idle at 470.67128
# A new job comes. Server waken up and works now at 470.73579
# Server is idle at 472.72303
# A new job comes. Server waken up and works now at 472.78547
# Server is idle at 473.12945
# A new job comes. Server waken up and works now at 473.19575
# Server is idle at 474.51479
# A new job comes. Server waken up and works now at 474.58126
# Server is idle at 475.45622
# A new job comes. Server waken up and works now at 475.52216
# Server is idle at 475.87401
# A new job comes. Server waken up and works now at 475.93801
# Server is idle at 476.24615
# A new job comes. Server waken up and works now at 476.31142
# Server is idle at 476.88876
# A new job comes. Server waken up and works now at 476.95303
# Server is idle at 477.32824
# A new job comes. Server waken up and works now at 477.39477
# Server is idle at 479.00498
# A new job comes. Server waken up and works now at 479.06990
# Server is idle at 479.34371
# A new job comes. Server waken up and works now at 479.40944
# Server is idle at 480.39194
# A new job comes. Server waken up and works now at 480.45481
# Server is idle at 480.85457
# A new job comes. Server waken up and works now at 480.91991
# Server is idle at 481.69912
# A new job comes. Server waken up and works now at 481.76249
# Server is idle at 482.07658
# A new job comes. Server waken up and works now at 482.14240
# Server is idle at 483.87425
# A new job comes. Server waken up and works now at 483.93973
# Server is idle at 485.07744
# A new job comes. Server waken up and works now at 485.13990
# Server is idle at 485.44441
# A new job comes. Server waken up and works now at 485.51021
# Server is idle at 486.01468
# A new job comes. Server waken up and works now at 486.07753
# Server is idle at 487.09502
# A new job comes. Server waken up and works now at 487.15852
# Server is idle at 487.75406
# A new job comes. Server waken up and works now at 487.81950
# Server is idle at 488.35040
# A new job comes. Server waken up and works now at 488.41522
# Server is idle at 489.20368
# A new job comes. Server waken up and works now at 489.26764
# Server is idle at 491.08485
# A new job comes. Server waken up and works now at 491.14955
# Server is idle at 492.59440
# A new job comes. Server waken up and works now at 492.65907
# Server is idle at 493.04406
# A new job comes. Server waken up and works now at 493.10658
# Server is idle at 493.87325
# A new job comes. Server waken up and works now at 493.93856
# Server is idle at 495.23083
# A new job comes. Server waken up and works now at 495.29587
# Server is idle at 497.14244
# A new job comes. Server waken up and works now at 497.20485
# Server is idle at 497.69666
# A new job comes. Server waken up and works now at 497.76115
# Server is idle at 498.81139
# A new job comes. Server waken up and works now at 498.87482
# Server is idle at 499.49294
# A new job comes. Server waken up and works now at 499.55848
# Server is idle at 500.14955
# A new job comes. Server waken up and works now at 500.21537
# Server is idle at 501.10538
# A new job comes. Server waken up and works now at 501.16795
# Server is idle at 501.46726
# A new job comes. Server waken up and works now at 501.53042
# Server is idle at 501.85612
# A new job comes. Server waken up and works now at 501.91912
# Server is idle at 502.94423
# A new job comes. Server waken up and works now at 503.00720
# Server is idle at 503.73801
# A new job comes. Server waken up and works now at 503.80128
# Server is idle at 504.57437
# A new job comes. Server waken up and works now at 504.64056
# Server is idle at 506.17616
# A new job comes. Server waken up and works now at 506.23913
# Server is idle at 507.59245
# A new job comes. Server waken up and works now at 507.65535
# Server is idle at 508.53613
# A new job comes. Server waken up and works now at 508.60177
# Server is idle at 509.46214
# A new job comes. Server waken up and works now at 509.52813
# Server is idle at 510.31927
# A new job comes. Server waken up and works now at 510.38536
# Server is idle at 510.72402
# A new job comes. Server waken up and works now at 510.78847
# Server is idle at 512.51845
# A new job comes. Server waken up and works now at 512.58090
# Server is idle at 513.00533
# ...
# Server is idle at 775.46097
# A new job comes. Server waken up and works now at 775.52725
# Server is idle at 775.98770
# A new job comes. Server waken up and works now at 776.05127
# Server is idle at 776.60083
# A new job comes. Server waken up and works now at 776.66736
# Server is idle at 777.00018
# A new job comes. Server waken up and works now at 777.06270
# Server is idle at 778.93448
# A new job comes. Server waken up and works now at 778.99688
# Server is idle at 780.72470
# A new job comes. Server waken up and works now at 780.78986
# Server is idle at 781.26217
# A new job comes. Server waken up and works now at 781.32869
# Server is idle at 781.70560
# A new job comes. Server waken up and works now at 781.76970
# Server is idle at 783.65594
# A new job comes. Server waken up and works now at 783.71970
# Server is idle at 784.04326
# A new job comes. Server waken up and works now at 784.10908
# Server is idle at 784.90781
# A new job comes. Server waken up and works now at 784.97410
# Server is idle at 785.34492
# A new job comes. Server waken up and works now at 785.40880
# Server is idle at 787.14002
# A new job comes. Server waken up and works now at 787.20621
# Server is idle at 789.02251
# A new job comes. Server waken up and works now at 789.08755
# Server is idle at 789.39254
# A new job comes. Server waken up and works now at 789.45662
# Server is idle at 789.79604
# A new job comes. Server waken up and works now at 789.85852
# Server is idle at 790.69167
# A new job comes. Server waken up and works now at 790.75604
# Server is idle at 792.51784
# A new job comes. Server waken up and works now at 792.58245
# Server is idle at 793.01294
# A new job comes. Server waken up and works now at 793.07687
# Server is idle at 793.68481
# A new job comes. Server waken up and works now at 793.75052
# Server is idle at 794.28890
# A new job comes. Server waken up and works now at 794.35197
# Server is idle at 795.10417
# A new job comes. Server waken up and works now at 795.17083
# Server is idle at 795.85351
# A new job comes. Server waken up and works now at 795.91815
# Server is idle at 796.80903
# A new job comes. Server waken up and works now at 796.87319
# Server is idle at 797.43161
# A new job comes. Server waken up and works now at 797.49596
# Server is idle at 798.00544
# A new job comes. Server waken up and works now at 798.06823
# Server is idle at 798.60906
# A new job comes. Server waken up and works now at 798.67480
# Server is idle at 799.70720
# A new job comes. Server waken up and works now at 799.77064
# Server is idle at 801.33131
# A new job comes. Server waken up and works now at 801.39713
# Server is idle at 801.97991
# A new job comes. Server waken up and works now at 802.04436
# Server is idle at 803.18627
# A new job comes. Server waken up and works now at 803.25085
# Server is idle at 803.59285
# A new job comes. Server waken up and works now at 803.65898
# Server is idle at 805.18277
# A new job comes. Server waken up and works now at 805.24837
# Server is idle at 805.61070
# A new job comes. Server waken up and works now at 805.67704
# Server is idle at 806.00347
# A new job comes. Server waken up and works now at 806.06594
# Server is idle at 806.57708
# A new job comes. Server waken up and works now at 806.64184
# Server is idle at 808.54295
# A new job comes. Server waken up and works now at 808.60790
# Server is idle at 809.02202
# A new job comes. Server waken up and works now at 809.08764
# Server is idle at 809.44445
# A new job comes. Server waken up and works now at 809.50950
# Server is idle at 811.20619
# A new job comes. Server waken up and works now at 811.27273
# Server is idle at 811.87917
# A new job comes. Server waken up and works now at 811.94413
# Server is idle at 813.24444
# A new job comes. Server waken up and works now at 813.30939
# Server is idle at 814.74488
# A new job comes. Server waken up and works now at 814.81124
# Server is idle at 816.03051
# A new job comes. Server waken up and works now at 816.09363
# Server is idle at 816.75284
# A new job comes. Server waken up and works now at 816.81626
# Server is idle at 817.99063
# A new job comes. Server waken up and works now at 818.05722
# Server is idle at 818.97205
# A new job comes. Server waken up and works now at 819.03835
# Server is idle at 820.01745
# A new job comes. Server waken up and works now at 820.08205
# Server is idle at 820.94203
# A new job comes. Server waken up and works now at 821.00752
# Server is idle at 821.71001
# A new job comes. Server waken up and works now at 821.77263
# Server is idle at 823.35325
# A new job comes. Server waken up and works now at 823.41879
# Server is idle at 825.05504
# A new job comes. Server waken up and works now at 825.11807
# Server is idle at 825.66543
# A new job comes. Server waken up and works now at 825.73150
# Server is idle at 826.83202
# A new job comes. Server waken up and works now at 826.89836
# Server is idle at 827.42416
# A new job comes. Server waken up and works now at 827.48989
# Server is idle at 828.06578
# A new job comes. Server waken up and works now at 828.13084
# Server is idle at 828.88826
# A new job comes. Server waken up and works now at 828.95251
# Server is idle at 829.26637
# A new job comes. Server waken up and works now at 829.33283
# Server is idle at 831.24320
# A new job comes. Server waken up and works now at 831.30735
# Server is idle at 832.91574
# A new job comes. Server waken up and works now at 832.98030
# Server is idle at 833.62060
# A new job comes. Server waken up and works now at 833.68696
# Server is idle at 834.02071
# A new job comes. Server waken up and works now at 834.08519
# Server is idle at 834.91075
# A new job comes. Server waken up and works now at 834.97519
# Server is idle at 835.50644
# A new job comes. Server waken up and works now at 835.57056
# Server is idle at 835.95479
# A new job comes. Server waken up and works now at 836.01720
# Server is idle at 836.46514
# A new job comes. Server waken up and works now at 836.53136
# Server is idle at 837.56331
# A new job comes. Server waken up and works now at 837.62785
# Server is idle at 839.12728
# A new job comes. Server waken up and works now at 839.19262
# Server is idle at 839.50628
# A new job comes. Server waken up and works now at 839.57107
# Server is idle at 840.93219
# A new job comes. Server waken up and works now at 840.99771
# Server is idle at 841.38697
# A new job comes. Server waken up and works now at 841.45052
# Server is idle at 841.90229
# A new job comes. Server waken up and works now at 841.96789
# Server is idle at 843.66572
# A new job comes. Server waken up and works now at 843.72998
# Server is idle at 844.05662
# A new job comes. Server waken up and works now at 844.12304
# Server is idle at 844.65205
# A new job comes. Server waken up and works now at 844.71475
# Server is idle at 845.55639
# A new job comes. Server waken up and works now at 845.62224
# Server is idle at 847.56052
# A new job comes. Server waken up and works now at 847.62655
# Server is idle at 847.94929
# A new job comes. Server waken up and works now at 848.01590
# Server is idle at 848.31304
# A new job comes. Server waken up and works now at 848.37919
# Server is idle at 849.50798
# A new job comes. Server waken up and works now at 849.57247
# Server is idle at 849.84708
# A new job comes. Server waken up and works now at 849.91015
# Server is idle at 850.64787
# A new job comes. Server waken up and works now at 850.71215
# Server is idle at 851.00129
# A new job comes. Server waken up and works now at 851.06577
# Server is idle at 852.45658
# A new job comes. Server waken up and works now at 852.52105
# Server is idle at 854.06930
# A new job comes. Server waken up and works now at 854.13267
# Server is idle at 856.04367
# A new job comes. Server waken up and works now at 856.10897
# Server is idle at 857.29480
# A new job comes. Server waken up and works now at 857.35857
# Server is idle at 858.54324
# A new job comes. Server waken up and works now at 858.60868
# Server is idle at 859.60603
# A new job comes. Server waken up and works now at 859.67232
# Server is idle at 860.74622
# A new job comes. Server waken up and works now at 860.81040
# Server is idle at 861.72913
# A new job comes. Server waken up and works now at 861.79213
# Server is idle at 862.95722
# A new job comes. Server waken up and works now at 863.02276
# Server is idle at 863.57639
# A new job comes. Server waken up and works now at 863.64226
# Server is idle at 864.12343
# A new job comes. Server waken up and works now at 864.18637
# Server is idle at 864.49555
# A new job comes. Server waken up and works now at 864.55932
# Server is idle at 866.23904
# A new job comes. Server waken up and works now at 866.30548
# Server is idle at 867.17114
# A new job comes. Server waken up and works now at 867.23516
# Server is idle at 868.39556
# A new job comes. Server waken up and works now at 868.46093
# Server is idle at 868.85338
# A new job comes. Server waken up and works now at 868.91764
# Server is idle at 869.21186
# A new job comes. Server waken up and works now at 869.27595
# Server is idle at 869.61663
# A new job comes. Server waken up and works now at 869.68199
# Server is idle at 870.00005
# A new job comes. Server waken up and works now at 870.06533
# Server is idle at 870.52398
# A new job comes. Server waken up and works now at 870.58927
# Server is idle at 871.32576
# A new job comes. Server waken up and works now at 871.39026
# Server is idle at 872.10675
# A new job comes. Server waken up and works now at 872.17331
# Server is idle at 873.43944
# A new job comes. Server waken up and works now at 873.50193
# Server is idle at 874.92466
# A new job comes. Server waken up and works now at 874.99120
# Server is idle at 875.67115
# A new job comes. Server waken up and works now at 875.73567
# Server is idle at 877.36009
# A new job comes. Server waken up and works now at 877.42345
# Server is idle at 877.89646
# A new job comes. Server waken up and works now at 877.95891
# Server is idle at 878.60506
# A new job comes. Server waken up and works now at 878.66744
# Server is idle at 879.75114
# A new job comes. Server waken up and works now at 879.81684
# Server is idle at 880.12037
# A new job comes. Server waken up and works now at 880.18520
# Server is idle at 880.47283
# A new job comes. Server waken up and works now at 880.53615
# Server is idle at 880.86594
# A new job comes. Server waken up and works now at 880.93039
# Server is idle at 881.51698
# A new job comes. Server waken up and works now at 881.58032
# Server is idle at 881.91707
# A new job comes. Server waken up and works now at 881.98224
# Server is idle at 882.95390
# A new job comes. Server waken up and works now at 883.01926
# Server is idle at 884.11503
# A new job comes. Server waken up and works now at 884.18025
# Server is idle at 884.53805
# A new job comes. Server waken up and works now at 884.60402
# Server is idle at 885.71908
# A new job comes. Server waken up and works now at 885.78398
# Server is idle at 886.21059
# A new job comes. Server waken up and works now at 886.27698
# Server is idle at 887.06266
# A new job comes. Server waken up and works now at 887.12660
# Server is idle at 888.50500
# A new job comes. Server waken up and works now at 888.56837
# Server is idle at 889.66523
# A new job comes. Server waken up and works now at 889.72821
# Server is idle at 890.44462
# A new job comes. Server waken up and works now at 890.50769
# Server is idle at 891.02136
# A new job comes. Server waken up and works now at 891.08451
# Server is idle at 892.46372
# A new job comes. Server waken up and works now at 892.52999
# Server is idle at 893.98623
# A new job comes. Server waken up and works now at 894.04874
# Server is idle at 895.08520
# A new job comes. Server waken up and works now at 895.14959
# Server is idle at 896.03507
# A new job comes. Server waken up and works now at 896.10172
# Server is idle at 896.55633
# A new job comes. Server waken up and works now at 896.61878
# Server is idle at 896.97947
# A new job comes. Server waken up and works now at 897.04266
# Server is idle at 897.79322
# A new job comes. Server waken up and works now at 897.85793
# Server is idle at 898.55084
# A new job comes. Server waken up and works now at 898.61444
# Server is idle at 900.52920
# A new job comes. Server waken up and works now at 900.59541
# Server is idle at 901.52805
# A new job comes. Server waken up and works now at 901.59361
# Server is idle at 902.95044
# A new job comes. Server waken up and works now at 903.01428
# Server is idle at 903.31429
# A new job comes. Server waken up and works now at 903.37955
# Server is idle at 903.67295
# A new job comes. Server waken up and works now at 903.73651
# Server is idle at 904.44624
# A new job comes. Server waken up and works now at 904.50920
# Server is idle at 906.48565
# A new job comes. Server waken up and works now at 906.55118
# Server is idle at 907.83582
# A new job comes. Server waken up and works now at 907.90014
# Server is idle at 908.99988
# A new job comes. Server waken up and works now at 909.06565
# Server is idle at 910.36673
# A new job comes. Server waken up and works now at 910.43252
# Server is idle at 910.74326
# A new job comes. Server waken up and works now at 910.80572
# Server is idle at 911.17334
# A new job comes. Server waken up and works now at 911.23980
# Server is idle at 911.60888
# A new job comes. Server waken up and works now at 911.67197
# Server is idle at 912.20070
# A new job comes. Server waken up and works now at 912.26702
# Server is idle at 913.47295
# A new job comes. Server waken up and works now at 913.53551
# Server is idle at 914.91691
# A new job comes. Server waken up and works now at 914.98115
# Server is idle at 916.19410
# A new job comes. Server waken up and works now at 916.25817
# Server is idle at 918.04367
# A new job comes. Server waken up and works now at 918.10668
# Server is idle at 919.26872
# A new job comes. Server waken up and works now at 919.33519
# Server is idle at 919.65428
# A new job comes. Server waken up and works now at 919.71837
# Server is idle at 920.84173
# A new job comes. Server waken up and works now at 920.90627
# Server is idle at 921.18241
# A new job comes. Server waken up and works now at 921.24891
# Server is idle at 921.88335
# A new job comes. Server waken up and works now at 921.94798
# Server is idle at 922.22531
# A new job comes. Server waken up and works now at 922.29081
# Server is idle at 922.61220
# A new job comes. Server waken up and works now at 922.67803
# Server is idle at 923.87398
# A new job comes. Server waken up and works now at 923.94020
# Server is idle at 924.46313
# A new job comes. Server waken up and works now at 924.52823
# Server is idle at 924.85212
# A new job comes. Server waken up and works now at 924.91477
# Server is idle at 926.30864
# A new job comes. Server waken up and works now at 926.37113
# Server is idle at 927.38711
# A new job comes. Server waken up and works now at 927.45069
# Server is idle at 929.37638
# A new job comes. Server waken up and works now at 929.44058
# Server is idle at 929.87561
# A new job comes. Server waken up and works now at 929.94113
# Server is idle at 930.83021
# A new job comes. Server waken up and works now at 930.89660
# Server is idle at 932.70260
# A new job comes. Server waken up and works now at 932.76781
# Server is idle at 934.62730
# A new job comes. Server waken up and works now at 934.69253
# Server is idle at 935.54802
# A new job comes. Server waken up and works now at 935.61227
# Server is idle at 936.47520
# A new job comes. Server waken up and works now at 936.54104
# Server is idle at 936.83125
# A new job comes. Server waken up and works now at 936.89754
# Server is idle at 938.82280
# A new job comes. Server waken up and works now at 938.88643
# Server is idle at 939.18305
# A new job comes. Server waken up and works now at 939.24601
# Server is idle at 939.96594
# A new job comes. Server waken up and works now at 940.03055
# Server is idle at 940.40688
# A new job comes. Server waken up and works now at 940.47301
# Server is idle at 941.01651
# A new job comes. Server waken up and works now at 941.08147
# Server is idle at 941.69680
# A new job comes. Server waken up and works now at 941.76325
# Server is idle at 942.57622
# A new job comes. Server waken up and works now at 942.63864
# Server is idle at 943.05796
# A new job comes. Server waken up and works now at 943.12405
# End at 944.03104805
# 0.0
